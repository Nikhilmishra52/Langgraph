# %%
splitter=RecursiveCharacterTextSplitter(chunk_size=1000,chunk_overlap=200)

# %%
chunks=splitter.split_documents(doc)

# %%
vectors=FAISS.from_documents(documents=chunks,embedding=embedding)

# %%
retriever=vectors.as_retriever()

# %%
retriever.invoke("tell me about the role")
# Out:
# [Document(id='db3dfafb-d550-4a1a-9ec9-18a110ee52c0', metadata={'producer': 'Skia/PDF m129', 'creator': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) HeadlessChrome/129.0.0.0 Safari/537.36', 'creationdate': '2025-07-28T07:47:47+00:00', 'title': 'AI/ML JD', 'moddate': '2025-07-28T07:47:47+00:00', 'source': 'C:\\Users\\nm478\\Downloads\\AIML JD .pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='Design,\xa0develop,\xa0and\xa0implement\xa0machine\xa0learning\xa0models\xa0for\xa0various\xa0agricultural\xa0\napplications\xa0(e.g.,\xa0crop\xa0classification,\xa0yield\xa0prediction,\xa0disease\xa0detection,\xa0advisory\xa0\ngeneration).\xa0\nWork\xa0with\xa0large\xa0datasets\xa0from\xa0diverse\xa0sources\xa0such\xa0as\xa0satellite\xa0imagery,\xa0drone\xa0footage,\xa0and'),
#  Document(id='de6d36c0-3c16-42ad-93c9-7c60be601b77', metadata={'producer': 'Skia/PDF m129', 'creator': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) HeadlessChrome/129.0.0.0 Safari/537.36', 'creationdate': '2025-07-28T07:47:47+00:00', 'title': 'AI/ML JD', 'moddate': '2025-07-28T07:47:47+00:00', 'source': 'C:\\Users\\nm478\\Downloads\\AIML JD .pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content='scikit-learn.\xa0\n● Good\xa0understanding\xa0of\xa0data\xa0preprocessing,\xa0model\xa0evaluation,\xa0and\xa0validation\xa0\ntechniques.\xa0\n● Experience\xa0with\xa0tools\xa0such\xa0as\xa0Jupyter,\xa0Git,\xa0and\xa0cloud\xa0platforms\xa0(AWS/GCP/Azure).\xa0\n● Strong\xa0analytical\xa0and\xa0problem-solving\xa0skills\xa0with\xa0a\xa0passion\xa0for\xa0applying\xa0AI\xa0for\xa0social\xa0\ngood.'),
#  Document(id='1e3f4a84-0da2-47e2-a548-f848b17e5a82', metadata={'producer': 'Skia/PDF m129', 'creator': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) HeadlessChrome/129.0.0.0 Safari/537.36', 'creationdate': '2025-07-28T07:47:47+00:00', 'title': 'AI/ML JD', 'moddate': '2025-07-28T07:47:47+00:00', 'source': 'C:\\Users\\nm478\\Downloads\\AIML JD .pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='Job\xa0Description \xa0 \nThis\xa0is\xa0a\xa0remote\xa0position.\xa0\nCall\xa0for\xa0Applications\xa0for\xa0Associate\xa0Machine\xa0Learning\xa0Engineer\xa0–\xa0ANNAM.AI\n\xa0\nLocation:\xa0ANNAM.AI,\xa0Center\xa0of\xa0Excellence\xa0in\xa0AI\xa0for\xa0Agriculture,\xa0IIT\xa0Ropar\nType:\xa0Full-Time\xa0|\xa0Contractual\xa0|\xa0Renewable\xa0based\xa0on\xa0performance\nCompensation:\xa0As\xa0per\xa0industry\xa0standards\nTenure:\xa0Initial\xa0appointment\xa0for\xa02\xa0years,\xa0extendable\xa0up\xa0to\xa05\xa0years\xa0depending\xa0on\xa0the\xa0project.\xa0\nRole\xa0Summary:\xa0\xa0\nWe\xa0are\xa0seeking\xa0enthusiastic\xa0and\xa0skilled\xa0Machine\xa0Learning\xa0Engineers\xa0to\xa0join\xa0our\xa0team.\xa0In\xa0this\xa0\nrole,\xa0you\xa0will\xa0work\xa0on\xa0developing\xa0and\xa0deploying\xa0AI/ML\xa0models\xa0that\xa0power\xa0intelligent\xa0\nagricultural\xa0systems.\xa0You\xa0will\xa0contribute\xa0directly\xa0to\xa0solving\xa0real-world\xa0agricultural\xa0challenges\xa0\nusing\xa0data-driven\xa0methods\xa0and\xa0play\xa0a\xa0key\xa0role\xa0in\xa0applying\xa0technology\xa0for\xa0social\xa0impact.\xa0\nKey\xa0Responsibilities:\nDesign,\xa0develop,\xa0and\xa0implement\xa0machine\xa0learning\xa0models\xa0for\xa0various\xa0agricultural\xa0\napplications\xa0(e.g.,\xa0crop\xa0classification,\xa0yield\xa0prediction,\xa0disease\xa0detection,\xa0advisory\xa0\ngeneration).'),
#  Document(id='220a3b7a-b27c-4a26-8fb8-c5973bbf5d42', metadata={'producer': 'Skia/PDF m129', 'creator': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) HeadlessChrome/129.0.0.0 Safari/537.36', 'creationdate': '2025-07-28T07:47:47+00:00', 'title': 'AI/ML JD', 'moddate': '2025-07-28T07:47:47+00:00', 'source': 'C:\\Users\\nm478\\Downloads\\AIML JD .pdf', 'total_pages': 3, 'page': 2, 'page_label': '3'}, page_content='Preferred\xa0Qualifications:\n\xa0\n● Exposure\xa0to\xa0LLMs,\xa0NLP,\xa0computer\xa0vision,\xa0remote\xa0sensing,\xa0or\xa0geospatial\xa0data.\xa0\n● Prior\xa0experience\xa0in\xa0building\xa0or\xa0adapting\xa0Foundation\xa0Models\xa0in\xa0text,\xa0speech\xa0or\xa0Geo\xa0AI\xa0or\xa0\nmulti-modal\xa0/\xa0multi-lingual\xa0models.\xa0\n● Experience\xa0working\xa0with\xa0agricultural\xa0or\xa0environmental\xa0datasets.\xa0\n● Familiarity\xa0with\xa0model\xa0deployment\xa0tools\xa0and\xa0frameworks\xa0such\xa0as\xa0Docker,\xa0Flask,\xa0or\xa0\nFastAPI.\xa0\nBenefits:\nBe\xa0part\xa0of\xa0a\xa0national\xa0initiative\xa0focused\xa0on\xa0innovation\xa0for\xa0public\xa0good.\xa0\nCollaborate\xa0with\xa0some\xa0of\xa0the\xa0brightest\xa0minds\xa0at\xa0IIT\xa0Ropar.\xa0\nTackle\xa0real-world\xa0problems\xa0with\xa0AI\xa0solutions\xa0that\xa0impact\xa0millions.\xa0\nOpportunity\xa0to\xa0contribute\xa0to\xa0research\xa0publications,\xa0open-source\xa0tools,\xa0and\xa0large-scale\xa0\nsocietal\xa0transformation.')]
