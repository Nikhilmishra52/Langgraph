# %% [markdown]
# # Lets start with tools and agents

# %%
from langchain_community.tools import WikipediaQueryRun
from langchain_community.utilities import WikipediaAPIWrapper

# %%
api_wrapper=WikipediaAPIWrapper()
tool=WikipediaQueryRun(api_wrapper=api_wrapper)

# %%
tool.args
# Out:
# {'query': {'description': 'query to look up on wikipedia',
#   'title': 'Query',
#   'type': 'string'}}

# %%
tool.invoke("langchain")
# Out:
# 'Page: LangChain\nSummary: LangChain is a software framework that helps facilitate the integration of large language models (LLMs) into applications. As a language model integration framework, LangChain\'s use-cases largely overlap with those of language models in general, including document analysis and summarization, chatbots, and code analysis.\n\n\n\nPage: Vector database\nSummary: A vector database, vector store or vector search engine is a database that uses the vector space model to store vectors (fixed-length lists of numbers) along with other data items. Vector databases typically implement one or more approximate nearest neighbor algorithms, so that one can search the database with a query vector to retrieve the closest matching database records.\nVectors are mathematical representations of data in a high-dimensional space. In this space, each dimension corresponds to a feature of the data, with the number of dimensions ranging from a few hundred to tens of thousands, depending on the complexity of the data being represented. A vector\'s position in this space represents its characteristics. Words, phrases, or entire documents, as well as images, audio, and other types of data, can all be vectorized.\nThese feature vectors may be computed from the raw data using machine learning methods such as feature extraction algorithms, word embeddings or deep learning networks. The goal is that semantically similar data items receive feature vectors close to each other.\nVector databases can be used for similarity search, semantic search, multi-modal search, recommendations engines, large language models (LLMs), object detection, etc.\n\nPage: Retrieval-augmented generation\nSummary: Retrieval-augmented generation (RAG) is a technique that enables large language models (LLMs) to retrieve and incorporate new information. With RAG, LLMs do not respond to user queries until they refer to a specified set of documents. These documents supplement information from the LLM\'s pre-existing training data. This allows LLMs to use domain-specific and/or updated information that is not available in the training data. For example, this helps LLM-based chatbots access internal company data or generate responses based on authoritative sources.\nRAG improves large language models (LLMs) by incorporating information retrieval before generating responses. Unlike LLMs that rely on static training data, RAG pulls relevant text from databases, uploaded documents, or web sources. According to Ars Technica, "RAG is a way of improving LLM performance, in essence by blending the LLM process with a web search or other document look-up process to help LLMs stick to the facts." This method helps reduce AI hallucinations, which have caused chatbots to describe policies that don\'t exist, or recommend nonexistent legal cases to lawyers that are looking for citations to support their arguments.\nRAG also reduces the need to retrain LLMs with new data, saving on computational and financial costs. Beyond efficiency gains, RAG also allows LLMs to include sources in their responses, so users can verify the cited sources. This provides greater transparency, as users can cross-check retrieved content to ensure accuracy and relevance.\nThe term RAG was first introduced in a 2020 research paper.'

# %% [markdown]
# # Youtube search tool

# %%
from langchain_community.tools import YouTubeSearchTool

# %%
tool2=YouTubeSearchTool()

# %%
tool2.name
# Out:
# 'youtube_search'

# %%
tool2.invoke("sunny savita")
# Out:
# "['https://www.youtube.com/watch?v=OtdnFtHOu40&pp=ygUMc3Vubnkgc2F2aXRh', 'https://www.youtube.com/watch?v=_kpxLkH5vY0&pp=ygUMc3Vubnkgc2F2aXRh']"

# %%
from langchain_community.tools import TavilySearchResults

# %%
tool3=TavilySearchResults()
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 tool3=TavilySearchResults()
#
# File ~\OneDrive\Desktop\langgraph\.venv\Lib\site-packages\langchain_core\_api\deprecation.py:221, in deprecated.<locals>.deprecate.<locals>.finalize.<locals>.warn_if_direct_instance(self, *args, **kwargs)
#     219     warned = True
#     220     emit_warning()
# --> 221 return wrapped(self, *args, **kwargs)
#
# File ~\OneDrive\Desktop\langgraph\.venv\Lib\site-packages\langchain_community\tools\tavily_search\tool.py:165, in TavilySearchResults.__init__(self, **kwargs)
#     160 if "tavily_api_key" in kwargs:
#     161     kwargs["api_wrapper"] = TavilySearchAPIWrapper(
#     162         tavily_api_key=kwargs["tavily_api_key"]
#     163     )
# --> 165 super().__init__(**kwargs)
#
# File ~\OneDrive\Desktop\langgraph\.venv\Lib\site-packages\langchain_core\tools\base.py:517, in BaseTool.__init__(self, **kwargs)
#     512     msg = (
#     513         "args_schema must be a subclass of pydantic BaseModel or "
#     514         f"a JSON schema dict. Got: {kwargs['args_schema']}."
#     515     )
#     516     raise TypeError(msg)
# --> 517 super().__init__(**kwargs)
#
# File ~\OneDrive\Desktop\langgraph\.venv\Lib\site-packages\langchain_core\load\serializable.py:116, in Serializable.__init__(self, *args, **kwargs)
#     114 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     115     """"""  # noqa: D419  # Intentional blank docstring
# --> 116     super().__init__(*args, **kwargs)
#
#     [... skipping hidden 1 frame]
#
# File ~\OneDrive\Desktop\langgraph\.venv\Lib\site-packages\pydantic\main.py:250, in BaseModel.__init__(self, **data)
#     248 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     249 __tracebackhide__ = True
# --> 250 validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     251 if self is not validated_self:
#     252     warnings.warn(
#     253         'A custom validator is returning a value other than `self`.\n'
#     254         "Returning anything other than `self` from a top level model validator isn't supported when validating via `__init__`.\n"
#     255         'See the `model_validator` docs (https://docs.pydantic.dev/latest/concepts/validators/#model-validators) for more details.',
#     256         stacklevel=2,
#     257     )
#
# ValidationError: 1 validation error for TavilySearchAPIWrapper
#   Value error, Did not find tavily_api_key, please add an environment variable `TAVILY_API_KEY` which contains it, or pass `tavily_api_key` as a named parameter. [type=value_error, input_value={}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.12/v/value_error

# %% [markdown]
# # Agent class

# %%
from langchain.agents import AgentType,load_tools,initialize_agent
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 from langchain.agents import AgentType,load_tools,initialize_agent
#
# File ~\OneDrive\Desktop\langgraph\.venv\Lib\site-packages\langchain\agents\load_tools.py:21
#      18 from typing import Any, Dict, List, Optional, Callable, Tuple
#      19 from mypy_extensions import Arg, KwArg
# ---> 21 from langchain.agents.tools import Tool
#      22 from langchain_core.language_models import BaseLanguageModel
#      23 from langchain.callbacks.base import BaseCallbackManager
#
# File ~\OneDrive\Desktop\langgraph\.venv\Lib\site-packages\langchain\agents\tools.py:6
#       2 from typing import List, Optional
#       4 from langchain_core.tools import BaseTool, Tool, tool
# ----> 6 from langchain.callbacks.manager import (
#       7     AsyncCallbackManagerForToolRun,
#       8     CallbackManagerForToolRun,
#       9 )
#      12 class InvalidTool(BaseTool):
#      13     """Tool that is run when invalid tool name is encountered by agent."""
#
# File ~\OneDrive\Desktop\langgraph\.venv\Lib\site-packages\langchain\callbacks\__init__.py:17
#      12 from langchain_core._api import LangChainDeprecationWarning
#      13 from langchain_core.callbacks import (
#      14     StdOutCallbackHandler,
#      15     StreamingStdOutCallbackHandler,
#      16 )
# ---> 17 from langchain_core.tracers.context import (
#      18     collect_runs,
#      19     tracing_enabled,
#      20     tracing_v2_enabled,
#      21 )
#      22 from langchain_core.tracers.langchain import LangChainTracer
#      24 from langchain.callbacks.file import FileCallbackHandler
#
# ImportError: cannot import name 'tracing_enabled' from 'langchain_core.tracers.context' (C:\Users\nm478\OneDrive\Desktop\langgraph\.venv\Lib\site-packages\langchain_core\tracers\context.py)

# %%
# %%sql

# %%
from dotenv import load_dotenv
load_dotenv()
from langchain_google_genai import ChatGoogleGenerativeAI
import os
llm = ChatGoogleGenerativeAI(model='gemini-2.5-flash',api_key=os.environ['GEMINI_API_KEY'])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[32], line 3
#       1 from dotenv import load_dotenv
#       2 load_dotenv()
# ----> 3 from langchain_google_genai import ChatGoogleGenerativeAI
#       4 import os
#       5 llm = ChatGoogleGenerativeAI(model='gemini-2.5-flash',api_key=os.environ['GEMINI_API_KEY'])
#
# File ~\OneDrive\Desktop\langgraph\.venv\Lib\site-packages\langchain_google_genai\__init__.py:1
# ----> 1 from langchain_google_genai.chat_models import ChatGoogleGenerativeAI
#       3 __all__ = ["ChatGoogleGenerativeAI"]
#
# File ~\OneDrive\Desktop\langgraph\.venv\Lib\site-packages\langchain_google_genai\chat_models.py:42
#      32 from langchain_core.messages import (
#      33     AIMessage,
#      34     AIMessageChunk,
#    (...)     39     HumanMessageChunk,
#      40 )
#      41 from langchain_core.outputs import ChatGeneration, ChatGenerationChunk, ChatResult
# ---> 42 from langchain_core.pydantic_v1 import Field, root_validator
#      43 from langchain_core.utils import get_from_dict_or_env
#      44 from tenacity import (
#      45     before_sleep_log,
#      46     retry,
#    (...)     49     wait_exponential,
#      50 )
#
# ModuleNotFoundError: No module named 'langchain_core.pydantic_v1'

# %%
tools = load_tools(['wikipedia'],llm=llm)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 tools = load_tools(['wikipedia'],llm=llm)
#
# NameError: name 'load_tools' is not defined
